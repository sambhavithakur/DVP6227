# %%
from IPython.core import prefilter
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df_data=pd.read_csv('/content/supermarket_sales - Sheet1.csv')
df_data.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
df_data.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
df_data.nunique()
# Out:
# Invoice ID                 1000
# Branch                        3
# City                          3
# Customer type                 2
# Gender                        2
# Product line                  6
# Unit price                  943
# Quantity                     10
# Tax 5%                      990
# Total                       990
# Date                         89
# Time                        506
# Payment                       3
# cogs                        990
# gross margin percentage       1
# gross income                990
# Rating                       61
# dtype: int64

# %%
df_data.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count              1000.000000   1000.000000  1000.00000
# mean                  4.761905     15.379369     6.97270
# std                   0.000000     11.708825     1.71858
# min                   4.761905      0.508500     4.00000
# ...

# %%
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
df_data['date'] = pd.to_datetime(df_data['Date'])

# %%
df_data['date'] = pd.to_datetime(df_data['date'])

# %%
df_data['day'] = (df_data['date']).dt.day
df_data['month'] = (df_data['date']).dt.month
df_data['year'] = (df_data['date']).dt.year

# %%
df_data['Time'] = pd.to_datetime(df_data['Time'])

# %%
df_data['Hour'] = (df_data['Time']).dt.hour

# %%
df_data['Hour'].nunique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7548d82f9311> in <cell line: 1>()
# ----> 1 df_data['Hour'].nunique()
#
# NameError: name 'df_data' is not defined

# %%
df_data['Hour'].unique()
# Out:
# array([13, 10, 20, 18, 14, 11, 17, 16, 19, 15, 12])

# %%
genderCount  = sns.lineplot(x="Hour",  y = 'Quantity',data =df_data).set_title("Product Sales per Hour")

# %%
genderCount  = sns.relplot(x="Hour",  y = 'Quantity', col= 'month' , row= 'Branch', kind="line", hue="Gender", style="Gender",data=df_data)

# %%
df_data.shape
# Out:
# (1000, 17)

# %%
df_data.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating', 'date', 'day', 'month', 'year', 'Hour'],
#       dtype='object')

# %%
df_data.duplicated().sum()
# Out:
# 0

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
sns.barplot(x='gross income',y='cogs',data=df_data,palette='cubehelix')
plt.xlabel('Product line',fontsize=18,fontweight="bold")
plt.ylabel('Quantity',fontsize=18,fontweight="bold")
plt.xticks(rotation=180)
plt.title('Sales of different products VS Quantity',fontsize=18,fontweight="bold")
plt.show()

# %%
# Out:
#                     Total
# Customer type
# Member         164223.444
# Normal         158743.305
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_9, *['Total'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
# ...

# %%
sns.barplot(x="Customer type", y="Total", estimator = sum, data=df_data)
# Out:
# <Axes: xlabel='Customer type', ylabel='Total'>

# %%
sns.swarmplot(x="Customer type",  y = "Rating",  hue = "City", data =df_data).set_title("Customer Type")
# Out:
# Text(0.5, 1.0, 'Customer Type')

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
sns.barplot(x='gross income',y='cogs',data=df_data,palette='cubehelix')
plt.xlabel('Product line',fontsize=18,fontweight="bold")
plt.ylabel('Quantity',fontsize=18,fontweight="bold")
plt.xticks(rotation=180)
plt.title('Sales of different products VS Quantity',fontsize=18,fontweight="bold")
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
sns.boxenplot(y = 'Quantity', x = 'Product line', data=df_data )
plt.xlabel('Product line',fontsize=18,fontweight="bold")
plt.ylabel('Quantity',fontsize=18,fontweight="bold")
plt.xticks(rotation=90)
plt.title('Sales of different products VS Quantity',fontsize=18,fontweight="bold")
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
sns.countplot(y = 'Product line', data=df_data, order = df_data['Product line'].value_counts().index )
plt.xlabel('Quantity',fontsize=18,fontweight="bold")
plt.ylabel('Product Line',fontsize=18,fontweight="bold")
plt.xticks(rotation=90)
plt.title('Sales of different products VS Quantity',fontsize=18,fontweight="bold")
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
sns.boxenplot(y = 'Product line', x = 'Total', data=df_data )
plt.xlabel('Product line',fontsize=18,fontweight="bold")
plt.ylabel('Quantity',fontsize=18,fontweight="bold")
plt.xticks(rotation=90)
plt.title('Sales of different products VS Quantity',fontsize=18,fontweight="bold")
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
sns.stripplot(y = 'Product line', x = 'Total', hue = 'Gender', data=df_data )
plt.xlabel('Total',fontsize=18,fontweight="bold")
plt.ylabel('Product line',fontsize=18,fontweight="bold")
plt.xticks(rotation=90)
plt.title('Sales of different products VS Total(groupby)',fontsize=18,fontweight="bold")
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
sns.relplot(y = 'Product line', x = 'gross income', data=df_data)
plt.xlabel('Gross income',fontsize=18,fontweight="bold")
plt.ylabel('Product line',fontsize=18,fontweight="bold")
plt.xticks(rotation=90)
plt.title('Sales of different products VS Quantity',fontsize=18,fontweight="bold")
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
sns.countplot(x="Payment", data =df_data).set_title("Payment Channel")
plt.xlabel('Payment',fontsize=18,fontweight="bold")
plt.ylabel('Counts',fontsize=18,fontweight="bold")
plt.xticks(rotation=90)
plt.title('Customer making payments',fontsize=18,fontweight="bold")
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
sns.countplot(x="Payment", hue = "Branch", data =df_data).set_title("Payment Channel by Branch")
plt.xlabel('Payment',fontsize=18,fontweight="bold")
plt.ylabel('Counts',fontsize=18,fontweight="bold")
plt.xticks(rotation=90)
plt.title('Customer making payments',fontsize=18,fontweight="bold")
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Sample dataset (replace this with your actual dataset)
df_data=pd.read_csv('/content/supermarket_sales - Sheet1.csv')

# Count the occurrences of each gender
gender_counts = df_data['Quantity'].value_counts()

# Create a pie chart
plt.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%')
plt.title('Quantity Distribution')
plt.axis('equal')  # Equal aspect ratio ensures that the pie is drawn as a circle.
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data
data = sns.load_dataset('diamonds')

# Create a boxen plot
plt.figure(figsize=(8, 6))
sns.boxenplot(x='cut', y='price', data=data)
plt.title('Boxen Plot of Diamond Prices by Cut')
plt.show()

# %%
sns.boxplot(x="Branch", y = "Rating" ,data =sales).set_title("Ratings by Branch")

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
sns.boxplot(x="Branch", y = "Rating" ,data =df_data).set_title("Ratings by Branch")
plt.xlabel('Braches',fontsize=18,fontweight="bold")
plt.ylabel('Ratungs',fontsize=18,fontweight="bold")
plt.xticks(rotation=90)
plt.title('Rating of branches',fontsize=18,fontweight="bold")
plt.show()

# %%
sns.countplot(x="Payment", data =df_data).set_title("Payment Channel")
# Out:
# Text(0.5, 1.0, 'Payment Channel')

# %%
genderCount  = sns.lineplot(x="Hour",  y = 'Quantity',data =sales).set_title("Product Sales per Hour")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-4d263deecf49> in <cell line: 1>()
# ----> 1 genderCount  = sns.lineplot(x="Hour",  y = 'Quantity',data =sales).set_title("Product Sales per Hour")
#
# NameError: name 'sns' is not defined

# %%
sns.set(style="darkgrid")       #style the plot background to become a grid
genderCount  = sns.countplot(x="Gender", data =df_data).set_title("Gender_Count")

# %%
corr = df_data.corr()
sns.heatmap(corr,annot=True,cmap='Reds')
# Out:
# <ipython-input-4-c27c71320d5f>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df_data.corr()
# <Axes: >

# %%
df_data.hist(figsize=(10,10),bins=50)
plt.show()

# %%
 df_data['Rating'].unique()
# Out:
# array([ 9.1,  9.6,  7.4,  8.4,  5.3,  4.1,  5.8,  8. ,  7.2,  5.9,  4.5,
#         6.8,  7.1,  8.2,  5.7,  4.6,  6.9,  8.6,  4.4,  4.8,  5.1,  9.9,
#         6. ,  8.5,  6.7,  7.7,  7.5,  7. ,  4.7,  7.6,  7.9,  6.3,  5.6,
#         9.5,  8.1,  6.5,  6.1,  6.6,  5.4,  9.3, 10. ,  6.4,  4.3,  4. ,
#         8.7,  9.4,  5.5,  8.3,  7.3,  4.9,  4.2,  9.2,  7.8,  5.2,  9. ,
#         8.8,  6.2,  9.8,  9.7,  5. ,  8.9])

# %%
ageDisSpend = sns.lineplot(x="Total", y = "Rating", data =df_data)
